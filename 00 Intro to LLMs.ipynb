# %% [markdown]
# ## INTRO TO LARGE LANGUAGE MODELS
# * LLM Training - model trained from a good chunk of the internet (the neural network becomes a compression of the internet)
#      * next word prediction task
# * LLM Dreams - mimicing / hallucinating the info from what it has trained from the internet
# * LLM Inference -
#      1) Next word prediction
#      2)

# %%
# www.databricks.com/glossary/llmops
# www.analyticsvidhya.com/blog/2023/09/llmops-for-machine-learning-engineering/

# %% [markdown]
# ## Steps of LLMOps:
# * Selection of Base Models:
#      * Exclusive / Proprietary Models
#      * Open Source Models
# * List of Tasks:
#      * Prompt Engineering
#      * Fine-tuning
#      * External Data
#      * Embeddings
#      * Alternatives
# * Model Evaluation:
# * Deployment & Monitoring:

# %% [markdown]
# ![image.png](attachment:fc63af15-5797-4c7d-a164-3b0047f08612.png)
